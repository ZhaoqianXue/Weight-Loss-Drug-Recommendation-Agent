# %%
import re
import ast
import json
import torch
from tqdm import tqdm
import pandas as pd
import numpy as np
from openai import OpenAI
from scipy.spatial.distance import cosine
from sklearn.preprocessing import normalize
from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoModel, AutoTokenizer
from sentence_transformers import SentenceTransformer, util
from sentence_transformers.util import cos_sim

# %% [markdown]
# ## Create an AE mapping list with embeddings

# %%
tirz_df = pd.read_excel('FAERS/Cleaned_Tirzepatide_AEs.xlsx')
sema_df = pd.read_excel('FAERS/Cleaned_Semaglutide_AEs.xlsx')
ozem_df = pd.read_excel('FAERS/Cleaned_Ozempic_AEs.xlsx')
rybe_df = pd.read_excel('FAERS/Cleaned_Rybelsus_AEs.xlsx')
wego_df = pd.read_excel('FAERS/Cleaned_Wegovy_AEs.xlsx')
zepb_df = pd.read_excel('FAERS/Cleaned_Zepbound_AEs.xlsx')
moun_df = pd.read_excel('FAERS/Cleaned_Mounjaro_AEs.xlsx')
lira_df = pd.read_excel('FAERS/Cleaned_Liraglutide_AEs.xlsx')
saxe_df = pd.read_excel('FAERS/Cleaned_Saxenda_AEs.xlsx')
vict_df = pd.read_excel('FAERS/Cleaned_Victoza_AEs.xlsx')

merged_df = pd.concat([tirz_df, sema_df, ozem_df, rybe_df, wego_df, zepb_df, moun_df, lira_df, saxe_df, vict_df], ignore_index=True)

merged_df = merged_df.drop_duplicates(subset=['AE', 'Reaction Group'])

merged_df.to_excel('FAERS/Merged_AEs.xlsx', index=False)

# %%
merged_df.shape
# Out:
# (5744, 2)

# %%
model = SentenceTransformer("pritamdeka/BioBERT-mnli-snli-scinli-scitail-mednli-stsb")
ae_texts = merged_df['AE'].dropna().astype(str).str.strip().tolist()

# %%
embeddings = []
for ae in tqdm(ae_texts, desc="Embedding AE terms"):
    emb = model.encode(ae, convert_to_numpy=True, normalize_embeddings=True)  # normalize for cosine sim
    embeddings.append(emb)
# Out:
# Embedding AE terms: 100%|███████████████████| 5744/5744 [02:56<00:00, 32.45it/s]

# %%
embedding_df = pd.DataFrame(embeddings, columns=[f'emb_{i}' for i in range(embeddings[0].shape[0])])
merged_df_clean = merged_df[merged_df['AE'].notna() & merged_df['AE'].str.strip().astype(bool)].reset_index(drop=True)
merged_df_embedded = pd.concat([merged_df_clean, embedding_df], axis=1)

# %%
merged_df_embedded
# Out:
#                                      AE  \
# 0           Incorrect Dose Administered
# 1                         Off Label Use
# 2               Extra Dose Administered
# 3                  Accidental Underdose
# 4           Product Dose Omission Issue
# ...                                 ...
# 5739                        Sirenomelia
# 5740                         Cystinuria
# 5741                    Hemihypertrophy
# 5742  Primary Immunodeficiency Syndrome
# 5743         Adenomatous Polyposis Coli
#
#                                       Reaction Group     emb_0     emb_1  \
# 0     Injury, Poisoning And Procedural Complications  0.046186  0.024490
# 1     Injury, Poisoning And Procedural Complications -0.005615  0.008708
# 2     Injury, Poisoning And Procedural Complications  0.030635  0.098102
# 3     Injury, Poisoning And Procedural Complications -0.029426  0.039857
# 4     Injury, Poisoning And Procedural Complications  0.018886  0.040606
# ...                                              ...       ...       ...
# 5739      Congenital, Familial And Genetic Disorders -0.031486  0.002704
# 5740      Congenital, Familial And Genetic Disorders  0.008056  0.042917
# 5741      Congenital, Familial And Genetic Disorders -0.075614  0.091777
# 5742      Congenital, Familial And Genetic Disorders -0.011655  0.019530
# 5743      Congenital, Familial And Genetic Disorders  0.035987  0.034287
#
#          emb_2     emb_3     emb_4     emb_5     emb_6     emb_7  ...  \
# 0    -0.034293 -0.059262  0.045288 -0.036910 -0.005737  0.018988  ...
# 1     0.001345 -0.042422  0.023932 -0.014669 -0.031821  0.028706  ...
# 2    -0.016347 -0.042228  0.025645 -0.025870 -0.003545 -0.040589  ...
# 3    -0.067074  0.005482  0.033095 -0.044396  0.020642  0.041145  ...
# 4    -0.000082  0.003330  0.014169 -0.004107 -0.048625  0.010183  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 5739 -0.042443  0.003822 -0.015004  0.006105 -0.026098 -0.026919  ...
# 5740 -0.005139 -0.006972  0.019351 -0.039403  0.043138  0.013969  ...
# 5741 -0.037417  0.038240 -0.033098 -0.025338  0.018138 -0.046948  ...
# 5742 -0.052403 -0.030324 -0.004203  0.037987 -0.040596 -0.016858  ...
# 5743 -0.008551  0.001487  0.048224 -0.030078 -0.053188 -0.004704  ...
#
#        emb_758   emb_759   emb_760   emb_761   emb_762   emb_763   emb_764  \
# 0    -0.031021  0.000022  0.012232  0.033662 -0.009992  0.062149  0.033643
# 1    -0.068366  0.029713 -0.004785 -0.034710 -0.001396 -0.013581 -0.018514
# 2    -0.033688 -0.019320  0.017733  0.003615 -0.010279  0.039942  0.016930
# 3    -0.004650 -0.064106 -0.034380 -0.004744 -0.047589  0.047966  0.014657
# 4    -0.071543 -0.005572 -0.021472  0.001818  0.019457  0.022574 -0.001305
# ...        ...       ...       ...       ...       ...       ...       ...
# 5739  0.013012 -0.008273  0.034310 -0.051014  0.014211 -0.037771  0.030668
# 5740 -0.019727 -0.008444 -0.009018  0.049898 -0.093023  0.008214 -0.002954
# 5741 -0.032225  0.009252  0.027699  0.051222  0.043186  0.002460 -0.059668
# 5742 -0.028685 -0.011615  0.045531  0.058467 -0.002097  0.042315  0.020588
# 5743 -0.002198  0.012416 -0.050657  0.081033 -0.078826  0.000734  0.008272
#
#        emb_765   emb_766   emb_767
# 0    -0.056486  0.074496  0.032124
# 1    -0.034237  0.029932  0.015402
# 2    -0.029881  0.027895  0.034040
# 3    -0.012151  0.041776  0.029654
# 4    -0.070922  0.030041 -0.006214
# ...        ...       ...       ...
# 5739  0.040231  0.012727  0.021520
# 5740  0.058993  0.026646 -0.022825
# 5741  0.019453 -0.004990  0.031824
# 5742  0.069731  0.020659  0.007519
# 5743  0.030725  0.058802 -0.021801
#
# [5744 rows x 770 columns]

# %%
merged_df_embedded.to_csv("FAERS/Merged_AEs_with_SentenceBioBERT.csv", index=False)

# %% [markdown]
# ## Match side effects with AEs

# %%
review_df = pd.read_csv("WebMD/combined_extracted_reviews.csv")
merged_df_embedded = pd.read_csv("FAERS/Merged_AEs_with_SentenceBioBERT.csv")

# %%
review_df['structured_info'] = review_df['structured_info'].apply(ast.literal_eval)

side_effects = []
for row in review_df['structured_info']:
    for item in row.get('side_effects', []):
        name = item.get('name')
        if name:
            side_effects.append(name.strip())

unique_side_effects = list(set(side_effects))

# %%
unique_side_effects
# Out:
# ['mild stomach upset',
#  'nerve pain',
#  'Sudden drop in glucose',
#  'vomitting',
#  'specific food cravings',
#  'feeling full',
#  'general uneasiness',
#  'muscle and joint pain',
#  'trouble controlling tantrums',
#  'injection site soreness',
#  'appetite loss',
#  'itching',
#  'itchy welt at injection site',
#  'severe constipation',
#  'skin sensitivity',
#  'tummy pains',
#  'extreme constipation',
#  'difficulty swallowing',
#  'heart burn',
#  'allergic reaction',
#  'diarrhea or constipation',
#  'tired',
#  'itchy swelling red at injection site',
#  'no appetite',
#  'heat burn',
#  'violent vomiting',
#  'Stomach upset',
#  'extreme vaginal bleeding',
#  'less energy',
#  'Feeling bad',
#  'cold sweats',
#  'joint and muscle pains',
#  'dry heaving',
#  'nausia',
#  'nausea',
#  'Reduced appetite',
#  'nauseous feeling',
#  'little hunger',
#  'weakness',
#  'projectile vomiting',
#  'slight hunger',
#  'burping (sulfer smell)',
#  'stomach craps',
#  'small bumps on the body',
#  'muscle aches',
#  'Muscle aches/pain',
#  'Nerve Pain',
#  'Vomiting',
#  'lower back pain',
#  'Tiredness',
#  'stomach cramps',
#  'vision blurry',
#  'No hunger',
#  'Upset stomach',
#  'Dry heaves',
#  'illness',
#  'uncontrollable diarrhea',
#  'increased hunger',
#  'irritation at injection site',
#  'swelling',
#  'strange steely/sweet taste in mouth',
#  'abdominal pain',
#  'HA',
#  'sulfur burps',
#  'Violent vomiting',
#  'extreme rash',
#  'rash on injection site',
#  'redness',
#  'low energy',
#  'brain fog',
#  'abdominal swelling',
#  'injection site rashes',
#  'bone chilling cold',
#  'Headaches',
#  'rapid heart rate',
#  'gastro intestinal issues',
#  'mild diarrhea',
#  'Intolerance to certain foods',
#  'stomach rolling',
#  'mild headache',
#  'stomach cramping',
#  'stomach problems',
#  'light headedness',
#  'high heart rate',
#  'stomach bloating and cramping',
#  'itchiness',
#  'exacerbation of rosacea',
#  'uncomfortable feeling after eating',
#  'malnutrition',
#  'tiredness',
#  'freezing cold feel',
#  'Depression',
#  'body aches',
#  'severe dehydration',
#  'headache',
#  'interrupted sleep',
#  'sudden outbursts of irritation',
#  'gastro issues',
#  'anxiety',
#  'UTI',
#  'Muscle aches',
#  'lack of energy',
#  'effected sleep',
#  'nausea/vomiting',
#  'unbearable stomach pain',
#  'No appetite',
#  'insomnia',
#  'rapid weight loss',
#  'migraines',
#  'apathy',
#  'upset stomach',
#  'Increased thirst',
#  'skin pain',
#  'Hunger',
#  'Lethargy',
#  'trouble controlling temper',
#  'weight gain',
#  'moodiness',
#  'hot flushes',
#  'muscle cramps',
#  'diabetic ketoacidosis',
#  'gastrointestinal issue',
#  'weird sensations in legs and feet',
#  'achiness',
#  'Distinct metal taste in mouth',
#  'vivid dreams',
#  'night sweats',
#  'gas',
#  'thirst',
#  'severe hunger pains',
#  'sluggish and fatigued',
#  'Pain',
#  'overall feeling of sickness',
#  'minor headache',
#  'light sensitivity',
#  'Feeling off',
#  'burping',
#  'fuzzy mind',
#  'lethargic',
#  'Itchy welt at injection site',
#  'stomach upset',
#  'injection site irritation',
#  'bulimia',
#  'Pressure in upper abdomen',
#  'sore shoulders, back and upper arms',
#  'softening of stools',
#  'aching legs and butt',
#  'weight loss',
#  'euphoria',
#  'exceptional tiredness',
#  'diarrhoea',
#  'general gassiness',
#  'no feeling hungry',
#  'muscle pain',
#  'GI side effects',
#  'undernourishment',
#  'sulphur burps',
#  'Constant hunger',
#  'excess skin',
#  'gas and bloating',
#  'extreme tiredness',
#  'lethargy',
#  'changes to appetite and cravings',
#  'Nervousness',
#  'tummy cramps',
#  'considerable intestinal discomfort',
#  'sour burping',
#  'intestinal cramps',
#  'muscle soreness',
#  'Gas',
#  'terrible breath',
#  'slow bowel movements',
#  'cotton mouth',
#  'mild nausea',
#  'Sluggishness',
#  'severe diarrhea',
#  'lack of appetite',
#  'vision changes',
#  'hypoglycemic shock',
#  'stomach pain',
#  'decreased appetite',
#  'digestion issues',
#  'hunger pangs',
#  'mania',
#  'loss of appetite',
#  'aching/twitching',
#  'Frequent bathroom use',
#  'Mild indigestion',
#  'low sugars',
#  'sour stomach',
#  'onocular episodes',
#  'muscle weakness',
#  'bloated feeling',
#  'body pain',
#  'abdominal cramping',
#  'Extreme vomiting',
#  'light headaches',
#  'deteriorated liver function',
#  'altered sleep',
#  'weak',
#  'watery stools',
#  'loss of desire to drink alcohol',
#  'decreased muscle mass',
#  'Hemorrhoids',
#  'abdominal cramps',
#  'flu like symptoms',
#  'Increased appetite',
#  'benefits seem to diminish',
#  'cramps',
#  'decrease of appetite',
#  'feel sick',
#  'Sulphur belches',
#  'GERD',
#  'fullness',
#  'Spoiled smell of dairy products',
#  'Decreased appetite',
#  'Lightheadedness',
#  'gassy',
#  'churning feeling in stomach',
#  'Weight loss',
#  'vaginal odor',
#  'dehydration',
#  'sulfer burps',
#  'unspecified',
#  'Inability to keep food down',
#  'Leg cramps',
#  'Acid reflux',
#  'sluggish',
#  'stopped sugar cravings',
#  'Achy and fatigued',
#  'sneezing',
#  'Minor burping',
#  'fatigue',
#  'sweats',
#  'Loss of appetite',
#  'throwing up',
#  'mildly quesy',
#  'stomach ache',
#  'increased heart rate',
#  'Sour stomach',
#  'indigestion',
#  'constipated',
#  'Feeling extremely warm',
#  'smaller food portions',
#  'Brain fog',
#  'burp farts',
#  'exhaustion after exercise',
#  'craving',
#  'Reduced food intake',
#  'increased stress',
#  'increased appetite',
#  'Burping',
#  'Lost appetite',
#  'no weight loss',
#  'the squits',
#  'sick',
#  'cramping',
#  'Increased blood sugar',
#  'severe pain in stomach',
#  'excessive vomiting',
#  'decreased libido',
#  'joint/muscle pain',
#  'Tightness in throat',
#  'itching at the site',
#  'stomach discomfort',
#  'severe abdominal pain',
#  'Constipation',
#  'freezing',
#  'PVCs (preventicular contractions)',
#  'unpleasant side effects',
#  'severe nausea',
#  'sulfur tasting belching',
#  'acid reflux',
#  'frequent bathroom visits',
#  'severe muscle pain',
#  'uneasy stomach',
#  'palpitations',
#  'no appetite suppression',
#  'Inability to hold food down',
#  'not really being hungry',
#  'uncontrollable watery diarrhoea',
#  'nose bleed',
#  'Exhaustion',
#  'heart palpitations',
#  'loss of strength',
#  'short temper',
#  'ringing in the ears',
#  'weight issues',
#  'bladder infection like symptoms',
#  'difficulty sleeping',
#  'Diarrhea',
#  'severe headache',
#  'burning and tingling tongue, throat, lips',
#  'itchy redness at the injection',
#  'sleep disturbances',
#  'sleep disruption',
#  'depression',
#  'hard belly',
#  'Nausea',
#  'Fatigue',
#  'shaking',
#  'sensitive skin',
#  'Visual changes',
#  'vision affected',
#  'back pain',
#  'excruciating tummy pain',
#  'inconsistent blood sugars',
#  'dry mouth',
#  'trouble waking',
#  'vomiting',
#  'sensitivity in feet',
#  'abdominal discomfort',
#  'feeling the need to burp',
#  'Hot flashes',
#  'hair loss',
#  'Thirst',
#  'muscle spasms',
#  'loss of cravings',
#  'foggy thought process',
#  'constant belching',
#  'digestive upset',
#  'dizziness',
#  'severe fatigue',
#  'stinging at injection site',
#  'Sleeplessness',
#  'jittery feeling',
#  'Cold extremities',
#  'blurry vision',
#  'stomach issues',
#  'heartburn',
#  'irregular bowel movements',
#  'loose bowel',
#  'Occasional constipation',
#  'Low glucose spikes',
#  'reflux',
#  'mild stomach pain',
#  'extreme diarrhea',
#  'Excruciating hip pain',
#  'constipation',
#  'sense of fullness',
#  'bad sulfur burps',
#  'changed appetite',
#  'fluctuating heart rate',
#  'stomach distress',
#  'High glucose spikes',
#  'Headache',
#  'liquid diarrhea',
#  'arthritis inflammation',
#  'decrease in appetite',
#  'gagging',
#  'back pains',
#  'feeling faint',
#  'Loose stool',
#  'severe belching',
#  'itchy, red blotch at injection site',
#  'stomach pains',
#  'extreme fatigue',
#  'belching',
#  'leg pain',
#  'general malaise',
#  'pain in back',
#  'gas burps',
#  'weakness due to hunger',
#  'strange taste in mouth',
#  'stomach cramp',
#  'joint pain',
#  'Full feeling',
#  'severe stomach issues',
#  'stomachaches',
#  'zero appetite',
#  'early satiety',
#  'Raised Thyroid TSH',
#  'nauseousness',
#  'swelling of feet and ankles',
#  'ruined taste buds',
#  'Stomach pain',
#  'Stomach cramps',
#  'lazy bowel mvt or severe constipation',
#  'deteriorated kidney function',
#  'burping indigestion',
#  'Dry mouth',
#  'occasional burping',
#  'Nausea from candy',
#  'feeling febrile',
#  'reduced appetite',
#  'hunger feeling loss',
#  'General unwellness',
#  'sensitive to touch',
#  'racing heart',
#  'decreased willingness to listen',
#  'eggy burps',
#  'small lump at injection site',
#  'sulfur belching',
#  'yeast infection',
#  'G.I. upset',
#  'energy loss',
#  'diarrhea',
#  'abnormal EKG',
#  'decreased eyesight',
#  'insatiable thirst',
#  'Body discomfort',
#  'increased energy',
#  'high blood pressure',
#  'infrequent stool',
#  'lightheadedness',
#  'chest pain',
#  'sluggishness',
#  'Adverse reaction to coffee',
#  'sleepless nights due to painful burping',
#  'achy',
#  'low blood pressure',
#  'sick to the stomach',
#  'Feeling over full',
#  'low blood sugar',
#  'Abdominal pain',
#  'Sleepiness',
#  'pain in Pancras',
#  'ED',
#  'gastric uneasiness',
#  'Extreme fatigue',
#  'sulfur taste',
#  'slight headache',
#  'mild constipation',
#  'vision issues',
#  'anorexia',
#  'eye floaters',
#  'injection anxiety',
#  'hypothermia',
#  'Bloating',
#  'digestive issues',
#  'headaches',
#  'sickness',
#  'distended abdomen',
#  'lump and redness around the injection site',
#  'hypoglycemia',
#  'sleepiness',
#  'heaviness on stomach',
#  'Heartburn',
#  'swollen stomach',
#  'loose stools',
#  'hunger',
#  'mild cramping',
#  'bloating',
#  'appetite suppression',
#  'acid feeling',
#  'Jittery',
#  'Indigestion',
#  'Weight gain',
#  'Dehydration',
#  'fuzzy vision',
#  'metallic taste in mouth',
#  'Reduced bowel movements',
#  'rash on cheeks',
#  'uncomfortable when eat too much',
#  'burps',
#  'stiff neck',
#  'Heart flutters',
#  'feeling super full',
#  'Dizziness',
#  'stomach gas build up']

# %%
ae_texts = merged_df_embedded['AE'].tolist()
ae_embeddings = merged_df_embedded[[f'emb_{i}' for i in range(768)]].dropna().values

# %%
results = []
threshold = 0

for effect in unique_side_effects:
    try:
        query_emb = model.encode(effect, convert_to_numpy=True, normalize_embeddings=True)

        similarities = np.dot(ae_embeddings, query_emb)

        top_indices = similarities.argsort()[::-1]
        top_matches = [(ae_texts[i], similarities[i]) for i in top_indices if similarities[i] >= threshold]
        top_matches = top_matches[:10]

        results.append({
            'Extracted Side Effect': effect,
            'Top Matches': top_matches
        })
    except Exception as e:
        results.append({
            'Extracted Side Effect': effect,
            'Top Matches': f"Error: {e}"
        })

# %%
for res in results[:20]:
    print(f"\nOriginal: {res['Extracted Side Effect']}")
    if isinstance(res['Top Matches'], str):
        print(f"  {res['Top Matches']}")
    elif not res['Top Matches']:
        print("  No match with similarity > 0.4")
    else:
        for match, score in res['Top Matches']:
            print(f"  Match: {match} (Similarity: {score:.4f})")
# Out:
# Original: mild stomach upset
#   Match: Epigastric Discomfort (Similarity: 0.6286)
#   Match: Dyspepsia (Similarity: 0.5667)
#   Match: Gastrointestinal Tract Irritation (Similarity: 0.5583)
#   Match: Stomach Mass (Similarity: 0.5531)
#   Match: Gastric Hypomotility (Similarity: 0.5405)
#   Match: Gastric Mucosa Erythema (Similarity: 0.5290)
#   Match: Obstruction Gastric (Similarity: 0.5248)
#   Match: Gastrointestinal Pain (Similarity: 0.5201)
#   Match: Gastric Hypermotility (Similarity: 0.5199)
#   Match: Gastrointestinal Hypomotility (Similarity: 0.5168)
#
# Original: nerve pain
#   Match: Nerve Compression (Similarity: 0.8377)
#   Match: Nerve Injury (Similarity: 0.7590)
#   Match: Peripheral Sensory Neuropathy (Similarity: 0.7265)
#   Match: Neuropathy Peripheral (Similarity: 0.7166)
#   Match: Spinal Pain (Similarity: 0.7144)
#   Match: Neuralgia (Similarity: 0.7005)
#   Match: Neck Pain (Similarity: 0.6906)
#   Match: Pain (Similarity: 0.6873)
#   Match: Sciatic Nerve Neuropathy (Similarity: 0.6770)
#   Match: Radicular Pain (Similarity: 0.6675)
#
# Original: Sudden drop in glucose
#   Match: Blood Glucose Decreased (Similarity: 0.6635)
#   Match: Shock Hypoglycaemic (Similarity: 0.6320)
#   Match: Hypoglycaemia (Similarity: 0.6253)
#   Match: Postprandial Hypoglycaemia (Similarity: 0.5948)
#   Match: Blood Glucose Fluctuation (Similarity: 0.5874)
#   Match: Hypoglycaemic Coma (Similarity: 0.5800)
#   Match: Hypoglycaemic Seizure (Similarity: 0.5715)
#   Match: Blood Glucagon Decreased (Similarity: 0.5706)
#   Match: Blood Glucose Abnormal (Similarity: 0.5675)
#   Match: Hyperglycaemic Crisis (Similarity: 0.5643)
#
# Original: vomitting
#   Match: Vomiting (Similarity: 0.9835)
#   Match: Self-Induced Vomiting (Similarity: 0.8148)
#   Match: Faecal Vomiting (Similarity: 0.8053)
#   Match: Vomiting Projectile (Similarity: 0.7772)
#   Match: Discoloured Vomit (Similarity: 0.7633)
#   Match: Cyclic Vomiting Syndrome (Similarity: 0.7615)
#   Match: Acetonaemic Vomiting (Similarity: 0.6858)
#   Match: Procedural Vomiting (Similarity: 0.6479)
#   Match: Nausea (Similarity: 0.6232)
#   Match: Prophylaxis Of Nausea And Vomiting (Similarity: 0.5475)
#
# Original: specific food cravings
#   Match: Food Craving (Similarity: 0.9341)
#   Match: Food Intolerance (Similarity: 0.5975)
#   Match: Food Interaction (Similarity: 0.5791)
#   Match: Food Allergy (Similarity: 0.5652)
#   Match: Food Aversion (Similarity: 0.5489)
#   Match: Adverse Food Reaction (Similarity: 0.5468)
#   Match: Hunger (Similarity: 0.5275)
#   Match: Taste Disorder (Similarity: 0.5203)
#   Match: Reaction To Food Additive (Similarity: 0.5113)
#   Match: Food Poisoning (Similarity: 0.5085)
#
# Original: feeling full
#   Match: Full Blood Count Increased (Similarity: 0.5318)
#   Match: Skin Warm (Similarity: 0.4561)
#   Match: Full Blood Count Abnormal (Similarity: 0.4444)
#   Match: Fumbling (Similarity: 0.4115)
#   Match: Feeling Hot (Similarity: 0.4090)
#   Match: Hyperaemia (Similarity: 0.3622)
#   Match: Mass (Similarity: 0.3602)
#   Match: Myoglobin Blood Increased (Similarity: 0.3599)
#   Match: Areflexia (Similarity: 0.3596)
#   Match: Increased Appetite (Similarity: 0.3564)
#
# Original: general uneasiness
#   Match: Unhealthy Diet (Similarity: 0.4403)
#   Match: Unhealthy Lifestyle (Similarity: 0.4192)
#   Match: General Physical Condition Abnormal (Similarity: 0.4152)
#   Match: Suspiciousness (Similarity: 0.4062)
#   Match: Unintentional Use For Unapproved Indication (Similarity: 0.4039)
#   Match: General Symptom (Similarity: 0.4028)
#   Match: Feelings Of Worthlessness (Similarity: 0.3965)
#   Match: Inappropriate Affect (Similarity: 0.3962)
#   Match: Nervousness (Similarity: 0.3921)
#   Match: Thinking Abnormal (Similarity: 0.3787)
#
# Original: muscle and joint pain
#   Match: Muscle Discomfort (Similarity: 0.7708)
#   Match: Musculoskeletal Pain (Similarity: 0.7540)
#   Match: Myofascial Pain Syndrome (Similarity: 0.7518)
#   Match: Musculoskeletal Discomfort (Similarity: 0.7090)
#   Match: Muscle Contracture (Similarity: 0.7015)
#   Match: Muscle Disorder (Similarity: 0.6863)
#   Match: Muscle Swelling (Similarity: 0.6836)
#   Match: Joint Swelling (Similarity: 0.6758)
#   Match: Musculoskeletal Disorder (Similarity: 0.6643)
#   Match: Muscle Injury (Similarity: 0.6585)
#
# Original: trouble controlling tantrums
#   Match: Tetany (Similarity: 0.4478)
#   Match: Dermatillomania (Similarity: 0.4134)
#   Match: Trichotillomania (Similarity: 0.4111)
#   Match: Tic (Similarity: 0.3859)
#   Match: Negative Thoughts (Similarity: 0.3836)
#   Match: Anxiety (Similarity: 0.3787)
#   Match: Anhedonia (Similarity: 0.3726)
#   Match: Skin Turgor Decreased (Similarity: 0.3705)
#   Match: Skin Discomfort (Similarity: 0.3702)
#   Match: Trismus (Similarity: 0.3624)
#
# Original: injection site soreness
#   Match: Injection Site Pain (Similarity: 0.8808)
#   Match: Injection Site Discomfort (Similarity: 0.8710)
#   Match: Injection Site Irritation (Similarity: 0.8634)
#   Match: Injection Site Injury (Similarity: 0.8354)
#   Match: Injection Site Induration (Similarity: 0.8346)
#   Match: Injection Site Ulcer (Similarity: 0.8345)
#   Match: Injection Site Swelling (Similarity: 0.8223)
#   Match: Injection Site Inflammation (Similarity: 0.8162)
#   Match: Injection Site Reaction (Similarity: 0.8112)
#   Match: Injection Site Infection (Similarity: 0.7919)
#
# Original: appetite loss
#   Match: Decreased Appetite (Similarity: 0.8509)
#   Match: Appetite Disorder (Similarity: 0.7208)
#   Match: Abnormal Loss Of Weight (Similarity: 0.6678)
#   Match: Weight Loss Poor (Similarity: 0.6170)
#   Match: Thirst Decreased (Similarity: 0.6079)
#   Match: Lack Of Satiety (Similarity: 0.6003)
#   Match: Fear Of Eating (Similarity: 0.5808)
#   Match: Hunger (Similarity: 0.5755)
#   Match: Weight Decreased (Similarity: 0.5677)
#   Match: Constipation (Similarity: 0.5672)
#
# Original: itching
#   Match: Itching Scar (Similarity: 0.8786)
#   Match: Injection Site Urticaria (Similarity: 0.6240)
#   Match: Skin Induration (Similarity: 0.6177)
#   Match: Infusion Site Urticaria (Similarity: 0.6171)
#   Match: Allodynia (Similarity: 0.6159)
#   Match: Urticaria (Similarity: 0.6085)
#   Match: Injection Site Pruritus (Similarity: 0.6080)
#   Match: Mechanical Urticaria (Similarity: 0.6058)
#   Match: Infusion Site Pruritus (Similarity: 0.5992)
#   Match: Pain Of Skin (Similarity: 0.5961)
#
# Original: itchy welt at injection site
#   Match: Itching Scar (Similarity: 0.7000)
#   Match: Injection Site Induration (Similarity: 0.6731)
#   Match: Injection Site Erythema (Similarity: 0.6592)
#   Match: Infusion Site Erythema (Similarity: 0.6491)
#   Match: Injection Site Pruritus (Similarity: 0.6376)
#   Match: Injection Site Eczema (Similarity: 0.6255)
#   Match: Injection Site Urticaria (Similarity: 0.6227)
#   Match: Infusion Site Pruritus (Similarity: 0.6218)
#   Match: Infusion Site Urticaria (Similarity: 0.6205)
#   Match: Injection Site Hypersensitivity (Similarity: 0.6181)
#
# Original: severe constipation
#   Match: Constipation (Similarity: 0.9302)
#   Match: Post Procedural Constipation (Similarity: 0.7182)
#   Match: Incontinence (Similarity: 0.6859)
#   Match: Irritable Bowel Syndrome (Similarity: 0.6596)
#   Match: Dyspepsia (Similarity: 0.6443)
#   Match: Rectal Obstruction (Similarity: 0.6383)
#   Match: Urinary Incontinence (Similarity: 0.6336)
#   Match: Urge Incontinence (Similarity: 0.6300)
#   Match: Defaecation Disorder (Similarity: 0.6260)
#   Match: Gastrointestinal Motility Disorder (Similarity: 0.6234)
#
# Original: skin sensitivity
#   Match: Sensitive Skin (Similarity: 0.8999)
#   Match: Skin Sensitisation (Similarity: 0.8276)
#   Match: Skin Reaction (Similarity: 0.7852)
#   Match: Skin Irritation (Similarity: 0.7789)
#   Match: Exposure Via Skin Contact (Similarity: 0.7734)
#   Match: Skin Discomfort (Similarity: 0.7146)
#   Match: Skin Disorder (Similarity: 0.7029)
#   Match: Skin Tightness (Similarity: 0.6969)
#   Match: Skin Lesion Inflammation (Similarity: 0.6939)
#   Match: Skin Lesion (Similarity: 0.6923)
#
# Original: tummy pains
#   Match: Tic (Similarity: 0.6285)
#   Match: Tetany (Similarity: 0.5830)
#   Match: Trigeminal Neuralgia (Similarity: 0.5435)
#   Match: Tracheal Disorder (Similarity: 0.5404)
#   Match: Thyroid Pain (Similarity: 0.5237)
#   Match: Trichotillomania (Similarity: 0.5209)
#   Match: Tremor (Similarity: 0.5078)
#   Match: Trismus (Similarity: 0.5056)
#   Match: Tension Headache (Similarity: 0.4982)
#   Match: Trigeminal Nerve Paresis (Similarity: 0.4835)
#
# Original: extreme constipation
#   Match: Constipation (Similarity: 0.9233)
#   Match: Post Procedural Constipation (Similarity: 0.6935)
#   Match: Incontinence (Similarity: 0.6633)
#   Match: Irritable Bowel Syndrome (Similarity: 0.6509)
#   Match: Gastrointestinal Hypermotility (Similarity: 0.6384)
#   Match: Dyspepsia (Similarity: 0.6373)
#   Match: Defaecation Urgency (Similarity: 0.6322)
#   Match: Defaecation Disorder (Similarity: 0.6274)
#   Match: Gastrointestinal Motility Disorder (Similarity: 0.6259)
#   Match: Urge Incontinence (Similarity: 0.6231)
#
# Original: difficulty swallowing
#   Match: Dysphagia (Similarity: 0.6893)
#   Match: Oropharyngeal Discomfort (Similarity: 0.5896)
#   Match: Pharyngeal Disorder (Similarity: 0.5787)
#   Match: Oral Discomfort (Similarity: 0.5720)
#   Match: Tongue Discomfort (Similarity: 0.5474)
#   Match: Swollen Tongue (Similarity: 0.5436)
#   Match: Impaired Gastric Emptying (Similarity: 0.5396)
#   Match: Pharyngeal Stenosis (Similarity: 0.5386)
#   Match: Oropharyngeal Pain (Similarity: 0.5377)
#   Match: Slow Speech (Similarity: 0.5377)
#
# Original: heart burn
#   Match: Thermal Burn (Similarity: 0.6243)
#   Match: Cardiogenic Shock (Similarity: 0.5993)
#   Match: Chemical Burn (Similarity: 0.5785)
#   Match: Burn Oesophageal (Similarity: 0.5766)
#   Match: Chemical Burn Of Skin (Similarity: 0.5636)
#   Match: Cardiac Contusion (Similarity: 0.5615)
#   Match: Myocardial Injury (Similarity: 0.5531)
#   Match: Cardiac Arrest (Similarity: 0.5500)
#   Match: Burn Of Internal Organs (Similarity: 0.5387)
#   Match: Heart Transplant (Similarity: 0.5356)
#
# Original: allergic reaction
#   Match: Allergic Oedema (Similarity: 0.8228)
#   Match: Dermatitis Allergic (Similarity: 0.7845)
#   Match: Multiple Allergies (Similarity: 0.7650)
#   Match: Allergic Reaction To Excipient (Similarity: 0.7446)
#   Match: Rhinitis Allergic (Similarity: 0.7431)
#   Match: Skin Reaction (Similarity: 0.7265)
#   Match: Dust Allergy (Similarity: 0.7251)
#   Match: Food Allergy (Similarity: 0.7214)
#   Match: Anaphylactoid Reaction (Similarity: 0.7210)
#   Match: Seasonal Allergy (Similarity: 0.7182)
